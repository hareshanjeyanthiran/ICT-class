# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv('Weather.csv')
weather.head()
# Out:
#           date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00         NaN                   73        63           1
# 1  18-05-2017 00:00         NaN                  251        63           1
# 2  18-05-2017 00:00         NaN                   75        56           1
# 3  18-05-2017 01:00         NaN                   98        56           1
# 4  18-05-2017 01:00         NaN                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15         0
# 1              27                    4          4       285.15         0
# 2               0                    1          1       285.15         0
# 3             351                    2          2       284.79         0
# 4             351                    1          1       284.79         0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %%
weather.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            199 non-null    str
#  1   is_holiday           0 non-null      float64
#  2   air_pollution_index  199 non-null    int64
#  3   humidity             199 non-null    int64
#  4   wind_speed           199 non-null    int64
#  5   wind_direction       199 non-null    int64
#  6   visibility_in_miles  199 non-null    int64
#  7   dew_point            199 non-null    int64
#  8   temperature          199 non-null    float64
#  9   rain_p_h             199 non-null    int64
#  10  snow_p_h             199 non-null    int64
#  11  clouds_all           199 non-null    int64
#  12  weather_type         199 non-null    str
#  13  weather_description  199 non-null    str
# dtypes: float64(2), int64(9), str(3)
# memory usage: 21.9 KB

# %%
sns.barplot(x=weather['weather_type'], y=weather['temperature'], color='blue')
# Out:
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %%
sns.histplot(weather['humidity'], color='green', kde=True)
# Out:
# <Axes: xlabel='humidity', ylabel='Count'>

# %%
sns.histplot(weather['humidity'], kde=False)  
sns.rugplot(weather['humidity'], color='darkblue')  
plt.show()

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], color='cyan')

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], color='lightblue',kind="hex")

# %%
sns.jointplot(x=weather['humidity'], y=weather['temperature'], color='darkblue',kind="kde")

# %%
sns.pairplot(weather[['humidity','temperature','air_pollution_index']])

# %%
sns.stripplot(x=weather['weather_type'], y=weather['temperature'], palette='summer')
# Out:
# C:\Users\Hareshan pc\AppData\Local\Temp\ipykernel_30324\3233213598.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x=weather['weather_type'], y=weather['temperature'], palette='summer')
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %%
sns.swarmplot(x=weather['weather_type'], y=weather['temperature'], palette='winter')
# Out:
# C:\Users\Hareshan pc\AppData\Local\Temp\ipykernel_30324\2449086581.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x=weather['weather_type'], y=weather['temperature'], palette='winter')
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %%
sns.countplot(x=weather['weather_type'])
# Out:
# <Axes: xlabel='weather_type', ylabel='count'>

# %%
sns.pointplot(x=weather['humidity'], y=weather['temperature'], hue=weather['weather_type'])
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.boxplot(x=weather['weather_type'], y=weather['temperature'])
# Out:
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %%
sns.lmplot(x='humidity', y='temperature', data=weather)
