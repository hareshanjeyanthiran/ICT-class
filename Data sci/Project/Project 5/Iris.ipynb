# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Iris = pd.read_csv(r'F:\Hareshan\ICT class\Data sci\Project\Project 5\Iris.csv')
Iris.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
sns.barplot(x=Iris['Species'], y=Iris['SepalLengthCm'], color='lightgreen')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.countplot(Iris['Species'])
# Out:
# <Axes: xlabel='count', ylabel='Species'>

# %%
sns.boxplot(x=Iris['Species'], y=Iris['SepalWidthCm'])
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.swarmplot(x=Iris['Species'], y=Iris['SepalWidthCm'])
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.histplot(Iris['SepalWidthCm'], color='green', kde=True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.jointplot(Iris['SepalWidthCm'], color='blue')

# %%
sns.pairplot(Iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']], hue='Species')
